# %%
data = pd.read_csv('Fonte IBGE/CAGEDEST_122018.txt', encoding = 'ISO-8859-1', decimal = ',', delimiter = ';')

# %%
data.columns
# Out:
# Index(['Admitidos/Desligados', 'Competência Declarada', 'Município',
#        'Ano Declarado', 'CBO 2002 Ocupação', 'CNAE 1.0 Classe',
#        'CNAE 2.0 Classe', 'CNAE 2.0 Subclas', 'Faixa Empr Início Jan',
#        'Grau Instrução', 'Qtd Hora Contrat', 'IBGE Subsetor', 'Idade',
#        'Ind Aprendiz', 'Ind Portador Defic', 'Raça Cor', 'Salário Mensal',
#        'Saldo Mov', 'Sexo', 'Tempo Emprego', 'Tipo Estab', 'Tipo Defic',
#        'Tipo Mov Desagregado', 'UF', 'Bairros SP', 'Bairros Fortaleza',
#        'Bairros RJ', 'Distritos SP', 'Regiões Adm DF', 'Mesorregião',
#        'Microrregião', 'Região Adm RJ', 'Região Adm SP', 'Região Corede',
#        'Região Corede 04', 'Região Gov SP', 'Região Senac PR',
#        'Região Senai PR', 'Região Senai SP', 'Sub-Região Senai PR',
#        'Ind Trab Parcial', 'Ind Trab Intermitente'],
#       dtype='object')

# %%
df = data[["Admitidos/Desligados","Salário Mensal","Município","Grau Instrução","Idade","Sexo","Tempo Emprego","Tipo Defic","UF"]]

# %%
df.head()
# Out:
#    Admitidos/Desligados  Salário Mensal  Município  Grau Instrução  Idade  \
# 0                     1           954.0     500215               6     24
# 1                     1          2500.0     500710               8     25
# 2                     1             0.0     500460               2     55
# 3                     1             0.0     500460               2     52
# 4                     1             0.0     500460               2     32
#
#    Sexo  Tempo Emprego  Tipo Defic  UF
# 0     1            0.0           0  50
# 1     1            0.0           0  50
# 2     1            0.0           0  50
# 3     1            0.0           0  50
# 4     1            0.0           0  50

# %%
df.corr()
# Out:
#                       Admitidos/Desligados  Salário Mensal  Município  \
# Admitidos/Desligados              1.000000        0.044920   0.009665
# Salário Mensal                    0.044920        1.000000   0.026354
# Município                         0.009665        0.026354   1.000000
# Grau Instrução                   -0.031150        0.184702  -0.012695
# Idade                             0.110487        0.151294  -0.012762
# Sexo                             -0.013509       -0.042394   0.027401
# Tempo Emprego                     0.332575        0.201733  -0.005550
# Tipo Defic                       -0.003351       -0.003491  -0.002667
# UF                                0.009635        0.024928   0.999744
#
#                       Grau Instrução     Idade      Sexo  Tempo Emprego  \
# Admitidos/Desligados       -0.031150  0.110487 -0.013509       0.332575
# Salário Mensal              0.184702  0.151294 -0.042394       0.201733
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2256752 entries, 0 to 2256751
# Data columns (total 42 columns):
# Admitidos/Desligados     int64
# Competência Declarada    int64
# Município                int64
# Ano Declarado            int64
# CBO 2002 Ocupação        int64
# CNAE 1.0 Classe          int64
# CNAE 2.0 Classe          int64
# CNAE 2.0 Subclas         int64
# Faixa Empr Início Jan    int64
# Grau Instrução           int64
# Qtd Hora Contrat         int64
# IBGE Subsetor            int64
# Idade                    int64
# Ind Aprendiz             int64
# Ind Portador Defic       int64
# Raça Cor                 int64
# Salário Mensal           float64
# Saldo Mov                int64
# Sexo                     int64
# Tempo Emprego            float64
# Tipo Estab               int64
# Tipo Defic               int64
# Tipo Mov Desagregado     int64
# UF                       int64
# Bairros SP               object
# Bairros Fortaleza        object
# ...

# %%
data.shape
# Out:
# (2256752, 42)

# %%
data.describe()
# Out:
#        Admitidos/Desligados  Competência Declarada     Município  \
# count          2.256752e+06              2256752.0  2.256752e+06
# mean           1.574103e+00               201812.0  3.553863e+05
# std            4.944784e-01                    0.0  8.300073e+04
# min            1.000000e+00               201812.0  1.100010e+05
# 25%            1.000000e+00               201812.0  3.147000e+05
# 50%            2.000000e+00               201812.0  3.531500e+05
# 75%            2.000000e+00               201812.0  4.117900e+05
# max            2.000000e+00               201812.0  5.300100e+05
#
#        Ano Declarado  CBO 2002 Ocupação  CNAE 1.0 Classe  CNAE 2.0 Classe  \
# count      2256752.0       2.256752e+06     2.256752e+06     2.256752e+06
# mean          2018.0       5.368213e+05     5.304958e+04     5.126839e+04
# std              0.0       1.784826e+05     2.269392e+04     2.468035e+04
# min           2018.0       3.011000e+04     1.112000e+03     1.113000e+03
# ...

# %%
data.head(10)
# Out:
#    Admitidos/Desligados  Competência Declarada  Município  Ano Declarado  \
# 0                     1                 201812     500215           2018
# 1                     1                 201812     500710           2018
# 2                     1                 201812     500460           2018
# 3                     1                 201812     500460           2018
# 4                     1                 201812     500460           2018
# 5                     1                 201812     500460           2018
# 6                     1                 201812     500460           2018
# 7                     1                 201812     500540           2018
# 8                     1                 201812     500460           2018
# 9                     1                 201812     500460           2018
#
#    CBO 2002 Ocupação  CNAE 1.0 Classe  CNAE 2.0 Classe  CNAE 2.0 Subclas  \
# 0             711210             1619             1610            161003
# ...

# %%
data.tail(10)
# Out:
#          Admitidos/Desligados  Competência Declarada  Município  \
# 2256742                     2                 201812     221100
# 2256743                     2                 201812     221100
# 2256744                     2                 201812     221100
# 2256745                     2                 201812     221100
# 2256746                     2                 201812     221100
# 2256747                     2                 201812     221100
# 2256748                     2                 201812     221100
# 2256749                     2                 201812     221100
# 2256750                     2                 201812     221100
# 2256751                     2                 201812     220770
#
#          Ano Declarado  CBO 2002 Ocupação  CNAE 1.0 Classe  CNAE 2.0 Classe  \
# 2256742           2018             524105            52159            47130
# 2256743           2018             513435            55220            56112
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data["Salário Mensal"])
# Out:
# pandas.core.series.Series

# %%
#Verificando se existe NaN  na coluna Salário Mensal
data['Salário Mensal'].isna().sum()
# Out:
# 0

# %%
#Verificando se existe Nulos na coluna Salário Mensal
data['Salário Mensal'].isnull().sum()
# Out:
# 0

# %%
data['Salário Mensal'].describe()
# Out:
# count    2.256752e+06
# mean     1.627244e+03
# std      2.097521e+03
# min      0.000000e+00
# 25%      1.066000e+03
# 50%      1.271000e+03
# 75%      1.600000e+03
# max      1.428300e+05
# Name: Salário Mensal, dtype: float64

# %%
data['Salário Mensal'].max()
# Out:
# 142830.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

salario = data['Salário Mensal']
#salario = data['Admitidos/Desligados']
#salario = data[data['Admitidos/Desligados'] == 1]['Salário Mensal']

# %%
#salario.hist(bins=150, range=(0,150000))
#data.plot.scatter(x='Salário Mensal', y='Idade')
data.plot.scatter(x='Sexo',y='Salário Mensal')

# %%
#salario.hist(bins=50, range=(1000,120000))
salario.hist(bins=50)

# %%
teste = data[data['Salário Mensal'] <= 6000]['Salário Mensal']
eixo_x = 'Salário'
sns.distplot(teste, axlabel = eixo_x);

# %%
teste.describe()
# Out:
# count    2.200448e+06
# mean     1.413742e+03
# std      6.407877e+02
# min      0.000000e+00
# 25%      1.063000e+03
# 50%      1.262000e+03
# 75%      1.556000e+03
# max      4.999000e+03
# Name: Salário Mensal, dtype: float64

# %%
teste.value_counts()
# Out:
# 954.0     95704
# 1500.0    24390
# 1200.0    24382
# 0.0       24245
# 1050.0    18745
# 1300.0    17894
# 1110.0    17597
# 1108.0    16460
# 1000.0    15681
# 477.0     15585
# 1100.0    14865
# 1185.0    12988
# 2000.0    12105
# 1405.0    10886
# 1400.0    10795
# 1800.0    10561
# 1150.0    10471
# 1752.0     8980
# 1250.0     8815
# 1600.0     8792
# 1440.0     8300
# 1107.0     8288
# 1020.0     8135
# 1030.0     7988
# 997.0      7865
# 1194.0     7822
# 990.0      7606
# 2500.0     7306
# 977.0      6843
# 1396.0     6826
#           ...
# 4496.0        7
# 4225.0        7
# 4737.0        7
# 4801.0        7
# 4962.0        7
# 4988.0        7
# 4821.0        6
# 4689.0        6
# 4976.0        6
# 4803.0        6
# 4794.0        6
# 4963.0        6
# 4936.0        6
# 4916.0        6
# 4399.0        6
# 4930.0        6
# 4929.0        6
# 4707.0        6
# 4443.0        6
# 4852.0        5
# 4904.0        5
# 4972.0        5
# 4933.0        5
# 4718.0        5
# ...

# %%
teste = data[data['Admitidos/Desligados'] == 1]['Salário Mensal']

# %%
teste = data[data['Salário Mensal'] == 0]['Salário Mensal']

# %%
salario = data['Admitidos/Desligados']

# %%
type(teste)
# Out:
# pandas.core.series.Series

# %%
teste.head(10)
# Out:
# Series([], Name: Salário Mensal, dtype: float64)

# %%
data.corr()
